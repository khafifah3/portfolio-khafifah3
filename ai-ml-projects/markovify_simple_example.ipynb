# %% [markdown]
# # Simple NLP project using Markovify

# %% [markdown]
# create a natural language based on text corpus Here recipe dataset is chosen.

# %% [markdown]
# ## Installing libraries and loading dataset

# %%
#region installing libraries
#!pip install pandas
#!pip install markovify
#endregion

# %%
import ast
import pandas as pd
import markovify

# %%
df = pd.read_csv('RAW_recipes.csv')

# Create a new dataframe with two columns
df1 = df[['name', 'steps']].copy()

# Remove missing values (NaN) for recipes with no description
df1 = df1.dropna(subset=['steps'])

# Choose a larger number of rows for modeling
n = 1000

# Process the data to tokenize sentences
data_subset = df1['steps'].iloc[0:n].apply(ast.literal_eval)
#print("\nprinting data subset:\n")
#print(data_subset)
#print("\n")

# Create a list of sentences
sentences = [sentence for sublist in data_subset for sentence in sublist]
#print("printing sentences:\n")
#print(sentences)

# Create a Markovify model # A state size of 2 means it looks at the previous two words to predict the next word.
text_model = markovify.Text(sentences, state_size=3)

# Generate text
for _ in range(5):
    print("\n")
    print(text_model.make_sentence())
# Out:
# heat oil in a frying pan , melt butter over med high heat
#
#
# i usually drain it over night , covered with plastic wrap
#
#
# cook in microwave on 50% power for 6 minutes at 350 deg f
#
#
# stir in onions , broccoli , mushrooms into bite size pieces
#
#
# spray an 8-inch square glass dish with cooking spray , add dough , cover with another layer of eggplant , etc
